# %% [markdown]
# <a href="https://colab.research.google.com/github/AayushPaigwar/CV-DL-Labs/blob/master/%5BCVDL%5D_Pract_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import PIL
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
#
import pathlib
# dataset_url = "https://www.kaggle.com/datasets/imsparsh/flowers-dataset/download?datasetVersionNumber=2"
# data_dir = tf.keras.utils.get_file('flowers-dataset', origin=dataset_url, extract=True)

dataset_url = "https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz"
data_dir = tf.keras.utils.get_file('flower_photos.tar', origin=dataset_url, extract=True)
data_dir = pathlib.Path(data_dir).with_suffix('')

#Path
print(data_dir)
# Out:
# ...
# 228813984/228813984 [==============================] - 1s 0us/step
# /root/.keras/datasets/flower_photos

# %%
image_count = len(list(data_dir.glob('*/*.png')))
print(image_count)
# Out:
# 0

# %%
daisy = list(data_dir.glob('daisy/*'))
PIL.Image.open(str(daisy[3]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x240>

# %%
PIL.Image.open(str(daisy[1]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=175x240>

# %%
PIL.Image.open(str(daisy[4]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x375>

# %%
tulips = list(data_dir.glob('tulips/*'))
PIL.Image.open(str(tulips[4]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x213>

# %%
PIL.Image.open(str(tulips[3]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=240x240>
